# %%
import numpy as np
import pandas as pd

# %%
pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/108.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/108.7 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/108.7 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/108.7 kB 325.1 kB/s eta 0:00:01
#      ------------- ----------------------- 41.0/108.7 kB 245.8 kB/s eta 0:00:01
#      --------------------------- --------- 81.9/108.7 kB 456.6 kB/s eta 0:00:01
#      ------------------------------------ 108.7/108.7 kB 449.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.1 MB 6.4 MB/s eta 0:00:02
#     --------------------------------------- 0.1/8.1 MB 1.7 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/8.1 MB 3.3 MB/s eta 0:00:03
#    -- ------------------------------------- 0.4/8.1 MB 2.3 MB/s eta 0:00:04
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 435.7 kB/s eta 0:00:01
#    ---- ---------------------------------- 30.7/294.9 kB 435.7 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/294.9 kB 297.7 kB/s eta 0:00:01
#    --------- ----------------------------- 71.7/294.9 kB 302.7 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.9 kB 502.3 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.9 kB 722.1 kB/s eta 0:00:01
#    ------------------------------------ - 286.7/294.9 kB 806.1 kB/s eta 0:00:01
#    -------------------------------------- 294.9/294.9 kB 729.9 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# ...

# %%
import seaborn as sns

# %%
df =pd.read_csv("dataset/data.csv")
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.nunique()
# Out:
# date               70
# price            1741
# bedrooms           10
# bathrooms          26
# sqft_living       566
# sqft_lot         3113
# floors              6
# waterfront          2
# view                5
# condition           5
# sqft_above        511
# sqft_basement     207
# yr_built          115
# yr_renovated       60
# street           4525
# city               44
# statezip           77
# country             1
# dtype: int64

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df_corr = df.select_dtypes(include='number').corr()
plt.figure(figsize=(10,8))
sns.heatmap(df_corr,annot=True)
plt.title ("Correlation Matrix")
plt.show()

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
colom_to_remove = ['date','yr_renovated', 'street', 'city',
       'statezip', 'country']
df = df.drop(columns=colom_to_remove)
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built
# 0     0          3        1340              0      1955
# 1     4          5        3370            280      1921
# 2     0          4        1930              0      1966
# 3     0          4        1000           1000      1963
# 4     0          4        1140            800      1976

# %%
import scipy.stats as stats
z_scores = stats.zscore(df)
thersshold = 3 
print("size befor removing outlaier", df.shape)
outlaier_df = df[(z_scores>thersshold).any(axis=1)]
df = df[(z_scores <= thersshold).all(axis =1)]
print("size after removing outlaier", df.shape)
# Out:
# size befor removing outlaier (4600, 12)
# size after removing outlaier (4244, 12)

# %%
outlaier_df.head()
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1    2384000.0       5.0       2.50         3650      9050     2.0
# 56    491500.0       4.0       1.75         2190    125452     1.0
# 100   736500.0       4.0       2.50         3180     21904     2.0
# 107  1090000.0       4.0       2.50         4340    141570     2.5
# 118  1030000.0       5.0       2.75         3190     16920     1.0
#
#      waterfront  view  condition  sqft_above  sqft_basement  yr_built
# 1             0     4          5        3370            280      1921
# 56            0     2          3        2190              0      1968
# 100           0     3          3        3180              0      2000
# 107           0     0          3        4340              0      1992
# 118           0     3          3        1690           1500      1976

# %%
from sklearn.preprocessing import StandardScaler
scalaer = StandardScaler()

scalaer.fit(df)

df_scaled = pd.DataFrame(scalaer.transform(df),columns=df.columns)

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
x = df.drop('price',axis=1)
y = df['price']

x_train , x_test ,y_train , y_test = train_test_split(x,y,train_size=0.25,random_state=42)

# %%
print("test data :")
print(x_test)

print("test data :")
print(x_train)
# Out:
# test data :
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 2156       2.0       2.00         1030     21712     1.0           0     0
# 4114       4.0       2.50         3180     31931     1.0           0     0
# 4531       4.0       2.75         2520     14021     2.0           0     0
# 186        4.0       2.00         2060      5000     1.0           0     0
# 2689       2.0       2.75         1430      1425     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 3995       3.0       1.75         1940      7500     1.5           0     0
# 3977       4.0       1.00         1660      4704     1.5           0     0
# 3123       4.0       3.50         3910     59863     2.0           0     0
# 2771       3.0       1.75         2920      9370     1.0           0     0
# 2885       5.0       3.00         3880     13000     2.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built
# ...

# %%
models =[
    ("RandomForest ",RandomForestRegressor()),
    ("LinearRegression",LinearRegression()),
    ("DecisionTree" , DecisionTreeRegressor()),
    ("KNN",KNeighborsRegressor())



]

# %%
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

# %%
for name,model in models:
    print(name)
    print()
    model.fit(x_train,y_train)
    y_pred = model.predict(x_test)
    print("mean sqt error: ", mean_squared_error(y_test,y_pred))
    print("")
    print("mean abb error: ", mean_absolute_error(y_test,y_pred))
    print("")
    print("R sqt error: ", r2_score(y_test,y_pred))
    print("")
# Out:
# RandomForest
#
# mean sqt error:  40339502430.70581
#
# mean abb error:  138848.4608340308
#
# R sqt error:  0.44064990087269995
#
# LinearRegression
#
# mean sqt error:  38930017963.13534
#
# mean abb error:  137660.36231526552
#
# R sqt error:  0.46019390189274767
#
# DecisionTree
#
# mean sqt error:  77510594067.26436
#
# mean abb error:  188623.7564172746
#
# R sqt error:  -0.07476681323512424
#
# KNN
#
# mean sqt error:  50578720840.17442
#
# mean abb error:  156674.39953793958
#
# R sqt error:  0.2986722490124528
